# %% [markdown]
# <a href="https://colab.research.google.com/github/Mayra-99/atelier_numpy/blob/main/atelier_numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Contexte Une entreprise dispose de plusieurs capteurs installés dans différents bâtiments. Les capteurs mesurent régulièrement la température, l'humidité, la pression et la consommation énergétique. Les données doivent être préparées et analysées avant d'être transmises à un futur système de Machine Learning permettant de détecter des situations anormales

# %% [markdown]
# Partie 1 : Listes Python vs tableaux NumPy On dispose des températures mesurées par un capteur : 24.5, 25.1, 26.3, 27.0 et 25.8
# 1) Créer une liste Python stockant ces températures;
#  2) Créer un tableau NumPy équivalent stockant ces températures ;
#  3) Effectuer une multiplication par 2 sur ces deux collections;
#   4) Quelle différence observe-t-on ?

# %%
# !pip install numpy

# %%
import numpy as np
